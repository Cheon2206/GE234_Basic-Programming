# %% [markdown]
# <a href="https://colab.research.google.com/github/Cheon2206/GE234_Basic-Programming/blob/main/GE234_Week2_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GE234: การโปรแกรมพื้นฐานสำหรับนักภูมิศาสตร์**
# ## **Week 2: Workshop เริ่มต้นเขียน Python ครั้งแรก**
# ---
# **ชื่อ-นามสกุล:** ชลิดา ทิตศานติกุล
#
# **รหัสนักศึกษา:** 6706614978
#
# **สาขาวิชา:** ภูมิศาวสตร์และภูมิสารสนเทศ
#
# ---
# **วัตถุประสงค์:**
# 1.  เข้าใจวิธีใช้งาน Google Colab เบื้องต้น
# 2.  เขียนคำสั่ง Python ง่ายๆ ได้ (Print, คำนวณเลข)
# 3.  รู้จัก "ตัวแปร" (Variables) ในการเก็บข้อมูล
# 4.  สร้างแผนที่ใบแรกของตัวเองได้!

# %% [markdown]
# ### **1. ให้คอมพิวเตอร์ "พูด" กับเรา (Print Function)**
# คำสั่งแรกที่โปรแกรมเมอร์ทั่วโลกต้องเรียนคือ `print()`
#
# คำสั่งนี้ใช้สั่งให้คอมพิวเตอร์แสดงผลข้อความออกมาทางหน้าจอ
#
# **วิธีใช้:**
# * พิมพ์ `print("ข้อความที่ต้องการ")`
# * อย่าลืมใส่เครื่องหมายคำพูด `""` หรือ `''` ครอบข้อความเสมอนะ

# %%
# กดปุ่ม Play ด้านหน้า (หรือกด Shift + Enter) เพื่อรันคำสั่ง
print("สวัสดี ธรรมศาสตร์")
print("Hello Geography TU")

# ลองแก้ข้อความข้างล่างนี้เป็นชื่อเล่นของตัวเองดูครับ
print("My name is Sittisak")
# Out:
# สวัสดี ธรรมศาสตร์
# Hello Geography TU
# My name is Sittisak

# %%
# กดปุ่ม Play ด้านหน้า (หรือกด Shift + Enter) เพื่อรันคำสั่ง
print("สวัสดี ยินดีที่ได้รู้จักนะ")
print("Hello, Nice to meet you.")

# ลองแก้ข้อความข้างล่างนี้เป็นชื่อเล่นของตัวเองดูครับ
print("My name is Chaleda")
# Out:
# สวัสดี ยินดีที่ได้รู้จักนะ
# Hello, Nice to meet you.
# My name is Chaleda

# %% [markdown]
# ### **2. Python คือเครื่องคิดเลข**
# เราสามารถใช้ Python คำนวณเลขได้เหมือนเครื่องคิดเลขเลย
# * บวก `+`
# * ลบ `-`
# * คูณ `*` (ใช้ดอกจัน)
# * หาร `/` (ใช้ Slash)

# %%
# การคำนวณพื้นฐาน
print(10 + 20)
print(2569 - 1998) # ลองคำนวณอายุ (ปีปัจจุบัน - ปีเกิด)

# การคำนวณทางภูมิศาสตร์ง่ายๆ
# สมมติระยะทางจริง 5000 เมตร ต้องการแปลงเป็น กิโลเมตร
print(5000 / 1000)
# Out:
# 30
# 571
# 5.0

# %%
# การคำนวณพื้นฐาน
print(100+50)
print(3790-1990)
print(13010*153)
print(7561/454)

print(2026 - 2006) # ลองคำนวณอายุ (ปีปัจจุบัน - ปีเกิด)

# การคำนวณทางภูมิศาสตร์ง่ายๆ
# สมมติระยะทางจริง 5000 เมตร ต้องการแปลงเป็น กิโลเมตร
print(50000 / 10000)
# Out:
# 150
# 1800
# 1990530
# 16.654185022026432
# 20
# 5.0

# %% [markdown]
# **❓ คำถามที่ 1:**
#
# ถ้าเรามีพื้นที่รูปสี่เหลี่ยม กว้าง 50 เมตร ยาว 100 เมตร
#
# จงเขียน Code ในช่องข้างล่างเพื่อคำนวณ **"พื้นที่ (Area)"**

# %%
# เขียนคำตอบตรงนี้ครับ (เอา 50 คูณ 100)
print( 50*100)
# Out:
# 5000

# %% [markdown]
# ### **3. ตัวแปร (Variables) = กล่องแปะป้ายชื่อ**
# ในงานภูมิศาสตร์ เรามีข้อมูลเยอะมาก เราจำตัวเลขทั้งหมดไม่ได้
#
# เราจึงต้องสร้าง "ตัวแปร" มาเก็บข้อมูลไว้
#
# **หลักการ:** `ชื่อตัวแปร = ค่าข้อมูล`
#
# เช่น:
# * `province = "Chiang Mai"` (เก็บชื่อจังหวัด)
# * `lat = 18.788` (เก็บพิกัดละติจูด)

# %%
# สร้างตัวแปรเก็บข้อมูลส่วนตัว
my_name = "Somchai"      # เปลี่ยนเป็นชื่อเรา
my_height = 170          # ส่วนสูง (ซม.)
my_province = "Bangkok"  # จังหวัดบ้านเกิด

# เอามาแสดงผลรวมกัน
print("ผมชื่อ", my_name)
print("มาจากจังหวัด", my_province)
# Out:
# ผมชื่อ Somchai
# มาจากจังหวัด Bangkok

# %%
# สร้างตัวแปรเก็บข้อมูลสเปคที่ชอบ
my_type = "หนุ่มตี๋"      # เปลี่ยนเป็นสเปคที่ชอบ

# เอามาแสดงผลรวมกัน
print("ผมชอบ", my_type, "😍")
# Out:
# ผมชอบ หนุ่มตี๋ 😍

# %% [markdown]
# **❓ คำถามที่ 2:**
#
# จงสร้างตัวแปรชื่อ `tu_age` เพื่อเก็บ **"อายุของมหาวิทยาลัยธรรมศาสตร์"**
#
# (ใบ้: ก่อตั้งปี 2477 ปัจจุบันปี 2569)

# %%
# 1. สร้างตัวแปร (เอาปีปัจจุบัน ลบ ปีที่ก่อตั้ง)
current_year = 2569
founding_year = 2477
tu_age = ... # (เติมคำตอบตรงนี้)

# 2. สั่ง Print แสดงผล
print("อายุ มธ. คือ", 2569-2477, "ปี")
# Out:
# อายุ มธ. คือ 92 ปี

# %% [markdown]
# ### **4. ชนิดของข้อมูล (Data Types)**
# คอมพิวเตอร์แยกแยะข้อมูลไม่เหมือนมนุษย์ มันมองแบบนี้:
#
# 1.  **Text (String)** -> ตัวหนังสือ เอามาคำนวณไม่ได้ (ต้องใส่ `""`)
#     * เช่น: ชื่อถนน, ชื่ออำเภอ, "101" (แบบนี้คือตัวหนังสือ)
# 2.  **Integer (int)** -> จำนวนเต็ม (นับคน, ปี พ.ศ.)
# 3.  **Float** -> ทศนิยม (พิกัด Lat/Lon, พื้นที่, อุณหภูมิ) **สำคัญมากในงาน GIS**

# %%
lat = 14.072  # พิกัด มธ.
student_count = 150
road_name = "Phahonyothin"

# ใช้คำสั่ง type() เพื่อดูว่าเป็นข้อมูลชนิดไหน
print(type(lat))
print(type(student_count))
print(type(road_name))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
Temp = 33.75
population = 15030
country_name = "Thailand"

# ใช้คำสั่ง type() เพื่อดูว่าเป็นข้อมูลชนิดไหน
print(type(Temp))
print(type(population))
print(type(country_name))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### **5. Workshop: สร้างแผนที่ใบแรก!**
# เราจะใช้ความรู้เรื่อง **ตัวแปร** และ **ชนิดข้อมูล (Float)** มาปักหมุดแผนที่กัน
#
# เราจะใช้ Library ชื่อ `folium` (เป็นเครื่องมือยอดฮิตของชาว Python GIS)

# %%
import folium # เรียกใช้เครื่องมือทำแผนที่

# 1. กำหนดพิกัด (ลองเปลี่ยนตัวเลขเป็นพิกัดบ้านตัวเองดูนะครับ)
# ไปหาพิกัดได้จาก Google Maps (คลิกขวาที่จุด > copy พิกัดแรกมา)
my_lat = 14.07264
my_lon = 100.60548

# 2. สร้างแผนที่
m = folium.Map(location=[my_lat, my_lon], zoom_start=15)

# 3. ปักหมุด (Marker)
folium.Marker(
    [my_lat, my_lon],
    popup="คณะของฉัน",
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

# 4. แสดงแผนที่
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d8f95f532cba8f778b5916272da3ac7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d8f95f532cba8f778b5916272da3ac7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d8f95f532cba8f778b5916272da3ac7 = L.map(
#                 &quot;map_8d8f95f532cba8f778b5916272da3ac7&quot;,
#                 {
#                     center: [14.07264, 100.60548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60c3dc7a0949a20301c0e08b72d1cc0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60c3dc7a0949a20301c0e08b72d1cc0a.addTo(map_8d8f95f532cba8f778b5916272da3ac7);
#
#
#             var marker_76c006849ed2c573d1c1eb19792b482a = L.marker(
#                 [14.07264, 100.60548],
#                 {
# }
#             ).addTo(map_8d8f95f532cba8f778b5916272da3ac7);
#
#
#             var icon_10098e8abdba1fcea6c487f51d668e3c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_665dbe1fb47ffaf2ad50a9648b6e36fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f760027ed6bbcfac2fbc049f91f75cb6 = $(`&lt;div id=&quot;html_f760027ed6bbcfac2fbc049f91f75cb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คณะของฉัน&lt;/div&gt;`)[0];
#                 popup_665dbe1fb47ffaf2ad50a9648b6e36fd.setContent(html_f760027ed6bbcfac2fbc049f91f75cb6);
#
#
#
#         marker_76c006849ed2c573d1c1eb19792b482a.bindPopup(popup_665dbe1fb47ffaf2ad50a9648b6e36fd)
#         ;
#
#
#
#
#                 marker_76c006849ed2c573d1c1eb19792b482a.setIcon(icon_10098e8abdba1fcea6c487f51d668e3c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium # เรียกใช้เครื่องมือทำแผนที่

# 1. กำหนดพิกัด (ลองเปลี่ยนตัวเลขเป็นพิกัดบ้านตัวเองดูนะครับ)
# ไปหาพิกัดได้จาก Google Maps (คลิกขวาที่จุด > copy พิกัดแรกมา)
my_lat = 14.065134818535643
my_lon = 100.60339496597877
# 2. สร้างแผนที่
m = folium.Map(location=[my_lat, my_lon], zoom_start=30)

# 3. ปักหมุด (Marker)
folium.Marker(
    [my_lat, my_lon],
    popup="V.K.P. Mansion",
    icon=folium.Icon(color='blue', icon='home')
).add_to(m)

# 4. แสดงแผนที่
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21d7593a2da2f0f44e1708a16ced11fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21d7593a2da2f0f44e1708a16ced11fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21d7593a2da2f0f44e1708a16ced11fe = L.map(
#                 &quot;map_21d7593a2da2f0f44e1708a16ced11fe&quot;,
#                 {
#                     center: [14.065134818535643, 100.60339496597877],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fdf4bbb57f5879c96861d82b2ea86d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fdf4bbb57f5879c96861d82b2ea86d2.addTo(map_21d7593a2da2f0f44e1708a16ced11fe);
#
#
#             var marker_fd249feb01e758a1b70c3272655db6bb = L.marker(
#                 [14.065134818535643, 100.60339496597877],
#                 {
# }
#             ).addTo(map_21d7593a2da2f0f44e1708a16ced11fe);
#
#
#             var icon_3f5601a2a747868f74acb42bc13d6201 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe34915061d4eadc824788d3d49dd558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_119a718fca00f5eea71d22c3cdec038e = $(`&lt;div id=&quot;html_119a718fca00f5eea71d22c3cdec038e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;V.K.P. Mansion&lt;/div&gt;`)[0];
#                 popup_fe34915061d4eadc824788d3d49dd558.setContent(html_119a718fca00f5eea71d22c3cdec038e);
#
#
#
#         marker_fd249feb01e758a1b70c3272655db6bb.bindPopup(popup_fe34915061d4eadc824788d3d49dd558)
#         ;
#
#
#
#
#                 marker_fd249feb01e758a1b70c3272655db6bb.setIcon(icon_3f5601a2a747868f74acb42bc13d6201);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **📝 การบ้านท้ายชั่วโมง**
# 1.  ให้แก้ไข Code ใน **Cell ข้างบน** (แผนที่)
# 2.  เปลี่ยนพิกัด `my_lat`, `my_lon` ให้เป็น **"บ้าน"** หรือ **"หอพัก"** ของนักศึกษาเอง
# 3.  เปลี่ยนข้อความใน `popup` จาก "คณะของฉัน" เป็นชื่อสถานที่นั้นๆ (เช่น "หอพัก City Park")
# 4.  กด Run ให้แผนที่แสดงผล แล้ว Save Notebook นี้ส่งใน Google Classroom ครับ
